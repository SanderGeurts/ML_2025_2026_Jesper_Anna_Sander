# %%
# Main code voor processen van de data
import uproot

file = uproot.open(r"Training_Data\FD_Training_Dpluspp7TeV_pT_2_3.root")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Main code voor processen van de data
# ----> 2 import uproot
#       4 file = uproot.open(r"Training_Data\FD_Training_Dpluspp7TeV_pT_2_3.root")
#
# ModuleNotFoundError: No module named 'uproot'
